# %% [markdown]
# In this notebook, I want to check whether every "C" papers are short papers. The answer is NO. For example, 10.1109/VAST50239.2020.00011, and 10.1109/vis49827.2021.9623273.
#
# Half of 3274 papers are Conference papers.
#
# One thing I noticed is that on IEEE, conference papers have "Date of Conference" whereas journal papers have "Date of Publication".
#
# Another thing worth mentioning is that in 2020, there are only 10 Conference papers; in 2019, there are only 9 conference papers. That's so weird.
#
# I originally thought that, at least for recent years, papers with DOIs like `10.1109/vis49827.2021.9623273` will be conference papers. However, that is not the case, for example, Cresentia's paper has a DOI of `10.1109/tvcg.2021.3114846`.

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
vispd = pd.read_csv("../../data/raw/vispubdata.csv")

# %%
vispd[vispd.PaperType == 'C'].sort_values(by=['Year']).tail(200)
# Out:
#      Conference  Year                                              Title  \
# 492        VAST  2008  Collaborative synthesis of visual analytic res...
# 1679       VAST  2008  Visual evaluation of text features for documen...
# 2581       VAST  2009  Geovisual analytics for self-organizing networ...
# 2660       VAST  2009  Using projection and 2D plots to visually reve...
# 1330       VAST  2009             Connecting the dots in visual analysis
# 1822       VAST  2009  LSAView: A tool for visual exploration of late...
# 877        VAST  2009  What's being said near "Martha"? Exploring nam...
# 330        VAST  2009  Visual opinion analysis of customer feedback data
# 1684       VAST  2009  SpRay: A visual analytics approach for gene ex...
# 445        VAST  2009  A framework for uncertainty-aware visual analy...
# 556        VAST  2009  Finding comparable temporal categorical record...
# 289        VAST  2009  Combining automated analysis and visualization...
# ...

# %%
dois_2021 = pd.read_csv("../../data/processed/dois_2021.csv")

# %%
dois_2021
# Out:
#     Conference  Year                                              Title  \
# 0          VIS  2021  Simultaneous Matrix Orderings for Graph Collec...
# 1          VIS  2021  IRVINE: Using Interactive Clustering and Label...
# 2          VIS  2021  Perception! Immersion! Empowerment! Superpower...
# 3          VIS  2021  Feature Curves and Surfaces of 3D Asymmetric T...
# 4          VIS  2021  Jurassic Mark: Inattentional Blindness for a D...
# 5          VIS  2021  AffectiveTDA: Using Topological Data Analysis ...
# 6          VIS  2021  Human-in-the-loop Extraction of Interpretable ...
# 7          VIS  2021  Towards Visual Explainable Active Learning for...
# 8          VIS  2021  M^2Lens: Visualizing and Explaining Multimodal...
# 9          VIS  2021  NeuroCartography: Scalable Automatic Visual Su...
# 10         VIS  2021  Visual Analytics for RNN-Based Deep Reinforcem...
# 11         VIS  2021  Task-Based Effectiveness of Interactive Contig...
# ...
