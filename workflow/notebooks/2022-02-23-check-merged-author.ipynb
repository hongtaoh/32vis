# %%
import pandas as pd
pd.options.display.max_colwidth = 500
import numpy as np

# %%
df = pd.read_csv('../../data/processed/merged_author_df.csv')

# %%
ieee = pd.read_csv('../../data/interim/ieee_author_df.csv')

# %%
df[(df['IEEE Author Affiliation Updated'].isnull()) & (
    df['First Institution Name Updated'].isnull()
) & (
    df['Raw Affiliation String Updated'].isnull()
)]
# Out:
# Empty DataFrame
# Columns: [Year, DOI, Title, IEEE Number of Authors, IEEE Author Position, IEEE Author Name, IEEE Author ID, IEEE Author Affiliation Updated, IEEE One Affiliation, Number of Authors, Author Name, Author Position, Author Position Type, OpenAlex Author ID, Author ORCID, Number of Affiliations, First Institution Name Updated, Raw Affiliation String Updated, First Institution ID, First Institution ROR, First Institution Type Updated, First Institution Country Code Updated, Binary Institution Type, IEEE Author Affiliation Filled]
# Index: []
#
# [0 rows x 24 columns]

# %%
df[df['IEEE Author Affiliation Updated'].isnull() ]
# Out:
#        Year                          DOI  \
# 11     1997   10.1109/VISUAL.1997.663860
# 94     1999   10.1109/VISUAL.1999.809883
# 279    1996   10.1109/VISUAL.1996.568113
# 285    1999   10.1109/VISUAL.1999.809894
# 291    1996   10.1109/VISUAL.1996.568124
# ...     ...                          ...
# 7783   2003  10.1109/INFVIS.2003.1249029
# 7791   2004      10.1109/VISUAL.2004.106
# 8276   2002  10.1109/VISUAL.2002.1183823
# 9980   1995   10.1109/VISUAL.1995.485147
# 10312  2019    10.1109/TVCG.2019.2934260
#
#                                                                                                                               Title  \
# 11                                                                             ROAMing terrain: Real-time Optimally Adapting Meshes
# 94                                                                         Multi-projector displays using camera-based registration
# ...

# %%
df[(df['IEEE Author Affiliation Updated'].isnull()) & (
    df['First Institution Name Updated'].notnull()) & (
    df['Raw Affiliation String Updated'].isnull()
)
]
# Out:
# Empty DataFrame
# Columns: [Year, DOI, Title, IEEE Number of Authors, IEEE Author Position, IEEE Author Name, IEEE Author ID, IEEE Author Affiliation Updated, IEEE One Affiliation, Number of Authors, Author Name, Author Position, Author Position Type, OpenAlex Author ID, Author ORCID, Number of Affiliations, First Institution Name Updated, Raw Affiliation String Updated, First Institution ID, First Institution ROR, First Institution Type Updated, First Institution Country Code Updated, Binary Institution Type, IEEE Author Affiliation Filled]
# Index: []
#
# [0 rows x 24 columns]

# %%
# df[df.DOI == '10.1109/VAST.2016.7883507']

# %%
df[(df['IEEE Author Affiliation Updated'].isnull()) & (
    df['Raw Affiliation String Updated'].notnull()
)]
# Out:
#        Year                          DOI  \
# 11     1997   10.1109/VISUAL.1997.663860
# 94     1999   10.1109/VISUAL.1999.809883
# 279    1996   10.1109/VISUAL.1996.568113
# 285    1999   10.1109/VISUAL.1999.809894
# 291    1996   10.1109/VISUAL.1996.568124
# ...     ...                          ...
# 7783   2003  10.1109/INFVIS.2003.1249029
# 7791   2004      10.1109/VISUAL.2004.106
# 8276   2002  10.1109/VISUAL.2002.1183823
# 9980   1995   10.1109/VISUAL.1995.485147
# 10312  2019    10.1109/TVCG.2019.2934260
#
#                                                                                                                               Title  \
# 11                                                                             ROAMing terrain: Real-time Optimally Adapting Meshes
# 94                                                                         Multi-projector displays using camera-based registration
# ...

# %%
df[(df['IEEE Author Affiliation Updated'].isnull()) & (
    df['First Institution Type Updated'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Year, DOI, Title, IEEE Number of Authors, IEEE Author Position, IEEE Author Name, IEEE Author ID, IEEE Author Affiliation Updated, IEEE One Affiliation, Number of Authors, Author Name, Author Position, Author Position Type, OpenAlex Author ID, Author ORCID, Number of Affiliations, First Institution Name Updated, Raw Affiliation String Updated, First Institution ID, First Institution ROR, First Institution Type Updated, First Institution Country Code Updated, Binary Institution Type, IEEE Author Affiliation Filled]
# Index: []
#
# [0 rows x 24 columns]

# %%
# I have raw string, but not country code
df[(df['IEEE Author Affiliation Updated'].isnull()) & (
    df['First Institution Country Code Updated'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Year, DOI, Title, IEEE Number of Authors, IEEE Author Position, IEEE Author Name, IEEE Author ID, IEEE Author Affiliation Updated, IEEE One Affiliation, Number of Authors, Author Name, Author Position, Author Position Type, OpenAlex Author ID, Author ORCID, Number of Affiliations, First Institution Name Updated, Raw Affiliation String Updated, First Institution ID, First Institution ROR, First Institution Type Updated, First Institution Country Code Updated, Binary Institution Type, IEEE Author Affiliation Filled]
# Index: []
#
# [0 rows x 24 columns]

# %%
df[df['IEEE DOI'].isnull()]
# Out:
# Empty DataFrame
# Columns: [IEEE Year, IEEE DOI, IEEE Title, IEEE Number of Authors, IEEE Author Position, IEEE Author Name, IEEE Author ID, IEEE Author Affiliation, IEEE One Affiliation, IEEE Paper Index, Year, DOI, Title, Number of Authors, Author Name, Author Position, Author Position Type, OpenAlex Author ID, Author ORCID, Number of Affiliations, First Institution Name, Raw Affiliation String, First Institution ID, First Institution ROR, First Institution Type, First Institution Country Code, Paper Index, Binary Institution Type]
# Index: []
#
# [0 rows x 28 columns]

# %%
# df['IEEE Paper Index'].tolist() == df['Paper Index'].tolist()
# Out:
# True

# %%
# df['IEEE Number of Authors'].tolist() == df['Number of Authors'].tolist()
# Out:
# True

# %%
# df['IEEE Author Position'].tolist() == df['Author Position'].tolist()
# Out:
# True

# %%
# df['new'] = np.where(
#     df['IEEE Author Affiliation'].notnull(),df['IEEE Author Affiliation'],df['Raw Affiliation String'])

# %%
df[df['IEEE Author Affiliation Filled'] != df['IEEE Author Affiliation Updated']]
# Out:
#        Year                          DOI  \
# 11     1997   10.1109/VISUAL.1997.663860
# 94     1999   10.1109/VISUAL.1999.809883
# 279    1996   10.1109/VISUAL.1996.568113
# 285    1999   10.1109/VISUAL.1999.809894
# 291    1996   10.1109/VISUAL.1996.568124
# ...     ...                          ...
# 7783   2003  10.1109/INFVIS.2003.1249029
# 7791   2004      10.1109/VISUAL.2004.106
# 8276   2002  10.1109/VISUAL.2002.1183823
# 9980   1995   10.1109/VISUAL.1995.485147
# 10312  2019    10.1109/TVCG.2019.2934260
#
#                                                                                                                               Title  \
# 11                                                                             ROAMing terrain: Real-time Optimally Adapting Meshes
# 94                                                                         Multi-projector displays using camera-based registration
# ...
