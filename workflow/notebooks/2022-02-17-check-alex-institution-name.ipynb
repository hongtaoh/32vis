# %%
import pandas as pd
import re
import csv
pd.options.display.max_columns = None
import numpy as np
from collections import Counter

# %%
alex = pd.read_csv('../../data/processed/openalex_author_df.csv')

# %%
# if there is type, there is name
alex[(alex['First Institution Type'].notnull()) & (
    alex['First Institution Name'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Year, DOI, Title, Number of Authors, Author Name, Author Position, Author Position Type, OpenAlex Author ID, Author ORCID, Number of Affiliations, First Institution Name, Raw Affiliation String, First Institution ID, First Institution ROR, First Institution Type, First Institution Country Code]
# Index: []

# %%
# if there is country code, there is name
alex[(alex['First Institution Country Code'].notnull()) & (
    alex['First Institution Name'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Year, DOI, Title, Number of Authors, Author Name, Author Position, Author Position Type, OpenAlex Author ID, Author ORCID, Number of Affiliations, First Institution Name, Raw Affiliation String, First Institution ID, First Institution ROR, First Institution Type, First Institution Country Code]
# Index: []

# %%
# how many unique institution types are there
type_list = alex['First Institution Type'].tolist()
Counter(type_list)
# Out:
# Counter({'education': 8325,
#          'company': 790,
#          nan: 2365,
#          'facility': 711,
#          'nonprofit': 79,
#          'government': 187,
#          'other': 17,
#          'healthcare': 85,
#          'archive': 12})

# %%
education = alex[alex['First Institution Type'].isin(['education'])]['First Institution Name'].tolist()
school_list = list(Counter(education).keys())
len(school_list)
# Out:
# 496

# %%
school_list[0].lower()
# Out:
# 'stanford university'

# %%
[i for i in school_list if 'university' not in i.lower()]
# Out:
# ['Georgia Institute of Technology',
#  'The Wallace H. Coulter Department of Biomedical Engineering',
#  'Worcester Polytechnic Institute',
#  'Technische Universität Darmstadt',
#  'Massachusetts Institute of Technology',
#  'ETH Zurich',
#  'California Institute of Technology',
#  'Weizmann Institute of Science',
#  'Technion – Israel Institute of Technology',
#  "École nationale de l'aviation civile",
#  'Virginia Tech',
#  'Dowling College',
#  'Harbin Institute of Technology',
#  'Universidade Federal do Rio Grande do Sul',
#  'Institute of Science and Technology Austria',
#  'Télécom ParisTech',
#  'École Centrale Paris',
#  "King's College London",
#  'Ulsan National Institute of Science and Technology',
#  'Rensselaer Polytechnic Institute',
#  'Katholieke Universiteit Leuven',
#  'Technische Universität München',
#  'Colorado School of Mines',
#  'KAIST',
#  'Universiti Putra Malaysia',
#  'Institut Eurécom',
#  'Université Paris-Saclay',
#  'Indian Institute of Science',
# ...

# %%
alex[alex['First Institution Name'] == 'China Academy of Art']
# Out:
#       Year                        DOI  \
# 6801  2016  10.1109/TVCG.2016.2598415
#
#                                                   Title  Number of Authors  \
# 6801  A Visual Analytics Approach for Understanding ...                  7
#
#        Author Name  Author Position Author Position Type  \
# 6801  Zhipeng Wang                5               middle
#
#                     OpenAlex Author ID Author ORCID  Number of Affiliations  \
# 6801  https://openalex.org/A2563802158          NaN                     1.0
#
#      First Institution Name     Raw Affiliation String  \
# 6801   China Academy of Art  China Academy of Art#TAB#
#
#                  First Institution ID      First Institution ROR  \
# 6801  https://openalex.org/I231293419  https://ror.org/01r61sr78
#
#      First Institution Type First Institution Country Code
# 6801              education                             CN

# %%
alex[alex.DOI == '10.1109/TVCG.2016.2598415']
# Out:
#       Year                        DOI  \
# 6797  2016  10.1109/TVCG.2016.2598415
# 6798  2016  10.1109/TVCG.2016.2598415
# 6799  2016  10.1109/TVCG.2016.2598415
# 6800  2016  10.1109/TVCG.2016.2598415
# 6801  2016  10.1109/TVCG.2016.2598415
# 6802  2016  10.1109/TVCG.2016.2598415
# 6803  2016  10.1109/TVCG.2016.2598415
#
#                                                   Title  Number of Authors  \
# 6797  A Visual Analytics Approach for Understanding ...                  7
# 6798  A Visual Analytics Approach for Understanding ...                  7
# 6799  A Visual Analytics Approach for Understanding ...                  7
# 6800  A Visual Analytics Approach for Understanding ...                  7
# 6801  A Visual Analytics Approach for Understanding ...                  7
# 6802  A Visual Analytics Approach for Understanding ...                  7
# 6803  A Visual Analytics Approach for Understanding ...                  7
#
# ...
