# %% [markdown]
# ## Aim
#
# - If there is raw string, will there be institution name? YES
# - If there is type, will there be institution name? YES
# - If there is country code, will there be institution name? YES
# - In 1260 rows, there is first institution name, but not country code.
# - In 1389 rows, there is first institution name, but not country code
# - Check the accuracy of raw_string - type/country code/institution name pairs. ALL CORRECT

# %%
import pandas as pd
import random
pd.options.display.max_colwidth = 200
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('../../data/interim/openalex_author_df.csv')
df.shape
# Out:
# (12406, 16)

# %% [markdown]
# ## As long as there is raw string, there is first institution name

# %%
df[(df['First Institution Name'].isnull()) & (df['Raw Affiliation String'].notnull())]
# Out:
# Empty DataFrame
# Columns: [Year, DOI, Title, Number of Authors, Author Name, Author Position, Author Position Type, OpenAlex Author ID, Author ORCID, Number of Affiliations, First Institution Name, Raw Affiliation String, First Institution ID, First Institution ROR, First Institution Type, First Institution Country Code]
# Index: []

# %% [markdown]
# ## As long as there is Type, there is first institution name

# %%
df[(df['First Institution Name'].isnull()) & (df['First Institution Type'].notnull())]
# Out:
# Empty DataFrame
# Columns: [Year, DOI, Title, Number of Authors, Author Name, Author Position, Author Position Type, OpenAlex Author ID, Author ORCID, Number of Affiliations, First Institution Name, Raw Affiliation String, First Institution ID, First Institution ROR, First Institution Type, First Institution Country Code]
# Index: []

# %% [markdown]
# ## As long as there is Country Code, there is first institution name

# %%
df[(df['First Institution Name'].isnull()) & (df['First Institution Country Code'].notnull())]
# Out:
# Empty DataFrame
# Columns: [Year, DOI, Title, Number of Authors, Author Name, Author Position, Author Position Type, OpenAlex Author ID, Author ORCID, Number of Affiliations, First Institution Name, Raw Affiliation String, First Institution ID, First Institution ROR, First Institution Type, First Institution Country Code]
# Index: []

# %% [markdown]
# ## In 1271 rows, there is first institution name, but not country code

# %%
df[(df['First Institution Name'].notnull()) & (df['First Institution Country Code'].isnull())].shape
# Out:
# (1271, 16)

# %% [markdown]
# ## In 1400 rows, there is first institution name, but not type

# %%
df[(df['First Institution Name'].notnull()) & (df['First Institution Type'].isnull())].shape
# Out:
# (1400, 16)

# %%
df[df['First Institution Name'].isnull()].shape
# Out:
# (656, 16)

# %%
df[df['Raw Affiliation String'].isnull()].shape
# Out:
# (664, 16)

# %% [markdown]
# ## Checking data accuracy

# %%
df = df[(df['First Institution Type'].notnull()) & (df['First Institution Country Code'].notnull())]
df.shape
# Out:
# (10350, 16)

# %%
df.sample(n=100, random_state=1234)
# Out:
#        Year                          DOI  \
# 6903   2002  10.1109/VISUAL.2002.1183781
# 5511   2010        10.1109/TVCG.2010.163
# 5565   2013        10.1109/TVCG.2013.164
# 972    2009        10.1109/TVCG.2009.187
# 3232   1997   10.1109/VISUAL.1997.663868
# 11079  2020    10.1109/TVCG.2020.3028955
# 10041  2018    10.1109/VAST.2018.8802449
# 8881   2015    10.1109/TVCG.2015.2466838
# 1848   2014    10.1109/TVCG.2014.2346441
# 10368  2019    10.1109/TVCG.2019.2934314
# 3094   2005  10.1109/INFVIS.2005.1532148
# 6988   2014    10.1109/TVCG.2014.2346324
# 3192   2007      10.1109/TVCG.2007.70519
# 1919   1996   10.1109/VISUAL.1996.568114
# 4570   2009        10.1109/TVCG.2009.136
# 6574   2012        10.1109/TVCG.2012.282
# 5184   2002  10.1109/VISUAL.2002.1183801
# 11892  2021     10.1109/mcg.2020.2985368
# 2419   2010        10.1109/TVCG.2010.159
# 10960  2020    10.1109/TVCG.2020.3030424
# 1291   1998   10.1109/VISUAL.1998.745327
# 11416  2020    10.1109/TVCG.2020.3030428
# ...

# %% [markdown]
# ## RESULTS
#
# - raw_string - type pairs, One is definitely wrong.
#     - VRVis Research Center; Vienna Austria, company? Yes
#     - [Zuse Institute Berlin](https://en.wikipedia.org/wiki/Zuse_Institute_Berlin), Berlin, Germany, facility?
#     - U S. Army Engineer Research and Development Center, facility?
#     - Inria, gov?
#     - Department of Informatics & Mohn Medical Imaging and Visualization Centre, healthcare?
#     - Institute of Mathematics and Computer Science in Medicine (IMDM)? This should be healthcare
#
# <!--     - Chinese Acad. of Science, I think it should be education, but also government.  -->
#
# - raw_string - country code pairs, two are absolutely wrong, the other two might be wrong
#     - Microsfot Asia, US?
#     - Institute of Mathematics and Computer Science in Medicine (IMDM), This should be DE
#     - IBM European Visualization Center, I guess this should be UK
#     - Inst. of Comput. Sci., Halle-Wittenberg Univ., Halle, Germany, this should be DE
#
# <!--     - Those from HK and Macau might be better coded speerately as HK and MO -->
#
# <!-- - All 100 raw_string - institution name pairs are correct -->
