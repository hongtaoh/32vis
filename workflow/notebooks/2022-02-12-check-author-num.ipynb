# %% [markdown]
# In this notebook, I want to compare the author number between df_alex and df_ieee.
#
# Something worth noticing:
#
# - In the paper of `10.1109/VAST.2014.7042494`, OpenAlex not only has the wrong number of authors; it also has wrong author positions. I am now wondering whether we can count on the author position info provided by OpenAlex.
#
# I also wrote the updatd df_ieee to file.

# %%
import pandas as pd
import re
import numpy as np

# %%
df_ieee = pd.read_csv('../../data/interim/ieee_author_df.csv')

# %%
df_alex = pd.read_csv('../../data/interim/openalex_author_df.csv')
# df_alex[df_alex.DOI == '10.1109/VISUAL.2005.1532816']

# %%
len(list(set(df_alex.DOI)))
# Out:
# 3233

# %%
len(list(set(df_ieee.DOI)))
# Out:
# 3232

# %%
[x for x in list(set(df_alex.DOI)) if x not in list(set(df_ieee.DOI))]
# Out:
# ['10.1109/VIS.1999.10000']

# %%
# alex_original = pd.read_csv('../../data/processed/openalex_author_df.csv')
# alex_original[alex_original.DOI == '10.1109/VISUAL.2005.1532816']

# %%
dois = list(set(df_alex.DOI))

# %%
df_ieee = df_ieee[df_ieee.DOI.isin(dois)].reset_index(drop=True)
len(list(set(df_ieee.DOI)))
# Out:
# 3232

# %%
diff_author_num_dict_list = []

# %%
for i in list(set(df_ieee.DOI)):
    ieee_n = df_ieee[df_ieee.DOI == i]['Number of Authors'].tolist()[0]
    alex_n = df_alex[df_alex.DOI == i]['Number of Authors'].tolist()[0]
    if ieee_n != alex_n:
        diff_author_num_dict = {
            'DOI': i,
            'URL': re.sub(r'^', 'https://doi.org/', i),
            'IEEE': ieee_n,
            'OpenAlex': alex_n
        }
        diff_author_num_dict_list.append(diff_author_num_dict)

# %%
diff_author_num_df = pd.DataFrame(diff_author_num_dict_list)

# %%
diff_author_num_df
# Out:
#                             DOI                                          URL  \
# 0    10.1109/VISUAL.1993.398857   https://doi.org/10.1109/VISUAL.1993.398857
# 1    10.1109/VISUAL.1998.745288   https://doi.org/10.1109/VISUAL.1998.745288
# 2         10.1109/TVCG.2008.157        https://doi.org/10.1109/TVCG.2008.157
# 3     10.1109/VAST.2018.8802509    https://doi.org/10.1109/VAST.2018.8802509
# 4     10.1109/VAST.2007.4389006    https://doi.org/10.1109/VAST.2007.4389006
# 5         10.1109/TVCG.2006.142        https://doi.org/10.1109/TVCG.2006.142
# 6         10.1109/TVCG.2006.173        https://doi.org/10.1109/TVCG.2006.173
# 7     10.1109/VAST.2012.6400554    https://doi.org/10.1109/VAST.2012.6400554
# 8         10.1109/TVCG.2006.187        https://doi.org/10.1109/TVCG.2006.187
# 9       10.1109/TVCG.2007.70552      https://doi.org/10.1109/TVCG.2007.70552
# 10   10.1109/VISUAL.1996.567598   https://doi.org/10.1109/VISUAL.1996.567598
# 11        10.1109/TVCG.2006.193        https://doi.org/10.1109/TVCG.2006.193
# 12    10.1109/TVCG.2021.3114849    https://doi.org/10.1109/TVCG.2021.3114849
# 13    10.1109/VAST.2008.4677359    https://doi.org/10.1109/VAST.2008.4677359
# 14  10.1109/INFVIS.2003.1249016  https://doi.org/10.1109/INFVIS.2003.1249016
# 15    10.1109/TVCG.2020.3030437    https://doi.org/10.1109/TVCG.2020.3030437
# 16    10.1109/VAST.2014.7042494    https://doi.org/10.1109/VAST.2014.7042494
# 17  10.1109/VISUAL.2005.1532816  https://doi.org/10.1109/VISUAL.2005.1532816
# 18  10.1109/VISUAL.2003.1250404  https://doi.org/10.1109/VISUAL.2003.1250404
# 19        10.1109/TVCG.2009.163        https://doi.org/10.1109/TVCG.2009.163
#
#     IEEE  OpenAlex
# 0      6         5
# 1      2         1
# 2      5         4
# 3      5         6
# 4      4         3
# 5      6         5
# 6      4         3
# 7      9         8
# 8      3         2
# 9      4         3
# 10     2         3
# 11     2         3
# 12     6         1
# 13     5         4
# 14     4         5
# 15    13        12
# 16     5         6
# 17     7        10
# 18     2         3
# 19     4         3

# %%
diff_author_num_df.DOI.tolist()
# Out:
# ['10.1109/VISUAL.1993.398857',
#  '10.1109/VISUAL.1998.745288',
#  '10.1109/TVCG.2008.157',
#  '10.1109/VAST.2018.8802509',
#  '10.1109/VAST.2007.4389006',
#  '10.1109/TVCG.2006.142',
#  '10.1109/TVCG.2006.173',
#  '10.1109/VAST.2012.6400554',
#  '10.1109/TVCG.2006.187',
#  '10.1109/TVCG.2007.70552',
#  '10.1109/VISUAL.1996.567598',
#  '10.1109/TVCG.2006.193',
#  '10.1109/TVCG.2021.3114849',
#  '10.1109/VAST.2008.4677359',
#  '10.1109/INFVIS.2003.1249016',
#  '10.1109/TVCG.2020.3030437',
#  '10.1109/VAST.2014.7042494',
#  '10.1109/VISUAL.2005.1532816',
#  '10.1109/VISUAL.2003.1250404',
#  '10.1109/TVCG.2009.163']

# %% [markdown]
# ## In terms of author number, after checking the original paper PDFs, I found that ieee is always correct, except for this one:
#
# - 10.1109/TVCG.2008.157, where IEEE website lists a first author who does not appear in the PDF.
#
# `ieee_df` misses info for `10.1109/VIS.1999.10000`, this is because the url directs me to a site other than ieee.org. The info on OPENALEX for this paper is correct.

# %% [markdown]
# ## Checking the one paper where IEEE is wrong and fix it

# %%
df_ieee[df_ieee.DOI == '10.1109/TVCG.2008.157']
# Out:
#       Year                    DOI  \
# 4126  2008  10.1109/TVCG.2008.157
# 4127  2008  10.1109/TVCG.2008.157
# 4128  2008  10.1109/TVCG.2008.157
# 4129  2008  10.1109/TVCG.2008.157
# 4130  2008  10.1109/TVCG.2008.157
#
#                                                   Title  Number of Authors  \
# 4126  Query-Driven Visualization of Time-Varying Ada...                5.0
# 4127  Query-Driven Visualization of Time-Varying Ada...                5.0
# 4128  Query-Driven Visualization of Time-Varying Ada...                5.0
# 4129  Query-Driven Visualization of Time-Varying Ada...                5.0
# 4130  Query-Driven Visualization of Time-Varying Ada...                5.0
#
#       Author Position       Author Name  \
# 4126              1.0      Miriah Meyer
# 4127              2.0    Luke J. Gosink
# 4128              3.0  John C. Anderson
# 4129              4.0     E. Wes Bethel
# 4130              5.0    Kenneth I. Joy
#
#                                            Author ID  \
# 4126  https://ieeexplore.ieee.org/author/37564728700
# 4127  https://ieeexplore.ieee.org/author/37395482900
# 4128  https://ieeexplore.ieee.org/author/37403588300
# 4129  https://ieeexplore.ieee.org/author/38550755500
# 4130  https://ieeexplore.ieee.org/author/37267811400
#
#                                      Author Affiliation One Affiliation
# 4126                                                NaN            True
# 4127  Institute for Data Analysis and Visualization ...            True
# 4128  Scientific Visualization Group, Berkeley Natio...            True
# 4129  Institute for Data Analysis and Visualization ...            True
# 4130  Institute for Data Analysis and Visualization ...            True

# %%
# Find the index of the row to drop
row_to_drop = df_ieee.index[df_ieee.DOI == '10.1109/TVCG.2008.157'].tolist()[0]
row_to_drop
# Out:
# 4126

# %%
# get the df_ieee after dropping that row
df_ieee_dropped = df_ieee.drop([row_to_drop])
df_ieee_dropped
# Out:
#        Year                         DOI  \
# 0      2011       10.1109/TVCG.2011.185
# 1      2011       10.1109/TVCG.2011.185
# 2      2011       10.1109/TVCG.2011.185
# 3      1991  10.1109/VISUAL.1991.175815
# 4      1991  10.1109/VISUAL.1991.175815
# ...     ...                         ...
# 12406  2007     10.1109/TVCG.2007.70578
# 12407  2009       10.1109/TVCG.2009.199
# 12408  2009       10.1109/TVCG.2009.199
# 12409  2009       10.1109/TVCG.2009.199
# 12410  1999      10.1109/VIS.1999.10000
#
#                                                    Title  Number of Authors  \
# 0                               D³ Data-Driven Documents                3.0
# 1                               D³ Data-Driven Documents                3.0
# 2                               D³ Data-Driven Documents                3.0
# 3      Tree-maps: a space-filling approach to the vis...                2.0
# 4      Tree-maps: a space-filling approach to the vis...                2.0
# ...                                                  ...                ...
# 12406                      Molecular Surface Abstraction                2.0
# 12407                      Visual Human+Machine Learning                3.0
# 12408                      Visual Human+Machine Learning                3.0
# 12409                      Visual Human+Machine Learning                3.0
# 12410  Progressive Compression of Arbitrary Triangula...                NaN
#
#        Author Position             Author Name  \
# 0                  1.0         Michael Bostock
# 1                  2.0        Vadim Ogievetsky
# 2                  3.0            Jeffrey Heer
# 3                  1.0              B. Johnson
# 4                  2.0          B. Shneiderman
# ...                ...                     ...
# 12406              2.0        Michael Gleicher
# 12407              1.0           Raphael Fuchs
# 12408              2.0            Jürgen Waser
# 12409              3.0  Meister Eduard Groller
# 12410              NaN                     NaN
#
#                                             Author ID  \
# 0      https://ieeexplore.ieee.org/author/37591067400
# 1      https://ieeexplore.ieee.org/author/38016292400
# 2      https://ieeexplore.ieee.org/author/37550791300
# 3      https://ieeexplore.ieee.org/author/37381975300
# 4      https://ieeexplore.ieee.org/author/37283016400
# ...                                               ...
# 12406  https://ieeexplore.ieee.org/author/37282585700
# 12407  https://ieeexplore.ieee.org/author/38099765400
# 12408  https://ieeexplore.ieee.org/author/38111592300
# 12409  https://ieeexplore.ieee.org/author/37282552200
# 12410                                             NaN
#
#                                       Author Affiliation One Affiliation
# 0      Computer Science Department, Stanford Universi...            True
# 1      Computer Science Department, Stanford Universi...            True
# 2      Computer Science Department, Stanford Universi...            True
# 3      Department of Computer Science & Human-Compute...            True
# 4      Department of Computer Science & Human-Compute...            True
# ...                                                  ...             ...
# 12406  Department of Computer Sciences, University of...            True
# 12407                            ETH Zurich, Switzerland            True
# 12408                              VRVis Vienna, Austria            True
# 12409         Technical University of of Vienna, Austria            True
# 12410                                                NaN             NaN
#
# [12410 rows x 9 columns]

# %%
# deduct 1 for number of authors
df_ieee_dropped.loc[df_ieee_dropped.DOI == '10.1109/TVCG.2008.157', 'Number of Authors'] -= 1

# %%
# deduct 1 for number of authors
df_ieee_dropped.loc[df_ieee_dropped.DOI == '10.1109/TVCG.2008.157', 'Author Position'] -= 1.0

# %%
# check whether the deduction of 1 for author num and author position works
# yes it does
df_ieee_dropped[df_ieee_dropped.DOI == '10.1109/TVCG.2008.157']
# Out:
#       Year                    DOI  \
# 4127  2008  10.1109/TVCG.2008.157
# 4128  2008  10.1109/TVCG.2008.157
# 4129  2008  10.1109/TVCG.2008.157
# 4130  2008  10.1109/TVCG.2008.157
#
#                                                   Title  Number of Authors  \
# 4127  Query-Driven Visualization of Time-Varying Ada...                4.0
# 4128  Query-Driven Visualization of Time-Varying Ada...                4.0
# 4129  Query-Driven Visualization of Time-Varying Ada...                4.0
# 4130  Query-Driven Visualization of Time-Varying Ada...                4.0
#
#       Author Position       Author Name  \
# 4127              1.0    Luke J. Gosink
# 4128              2.0  John C. Anderson
# 4129              3.0     E. Wes Bethel
# 4130              4.0    Kenneth I. Joy
#
#                                            Author ID  \
# 4127  https://ieeexplore.ieee.org/author/37395482900
# 4128  https://ieeexplore.ieee.org/author/37403588300
# 4129  https://ieeexplore.ieee.org/author/38550755500
# 4130  https://ieeexplore.ieee.org/author/37267811400
#
#                                      Author Affiliation One Affiliation
# 4127  Institute for Data Analysis and Visualization ...            True
# 4128  Scientific Visualization Group, Berkeley Natio...            True
# 4129  Institute for Data Analysis and Visualization ...            True
# 4130  Institute for Data Analysis and Visualization ...            True

# %%
## update df_ieee
df_ieee = df_ieee_dropped
df_ieee.shape
# Out:
# (12410, 9)

# %% [markdown]
# ## Fill the missing info for `10.1109/VIS.1999.10000`

# %%
df_ieee[df_ieee['DOI'] == '10.1109/VIS.1999.10000']
# Out:
#        Year                     DOI  \
# 12410  1999  10.1109/VIS.1999.10000
#
#                                                    Title  Number of Authors  \
# 12410  Progressive Compression of Arbitrary Triangula...                NaN
#
#        Author Position Author Name Author ID Author Affiliation  \
# 12410              NaN         NaN       NaN                NaN
#
#       One Affiliation
# 12410             NaN

# %%
fill_data = [
    {
        'Year': 1999,
        'DOI': '10.1109/VIS.1999.10000',
        'Title': 'Progressive Compression of Arbitrary Triangular Meshes',
        'Number of Authors': 3,
        'Author Position': 1,
        'Author Name': 'Daniel Cohen-Or',
        'Author ID': np.NaN,
        'Author Affiliation': 'Tel Aviv University',
        'One Affiliation': True,
    },
    {
        'Year': 1999,
        'DOI': '10.1109/VIS.1999.10000',
        'Title': 'Progressive Compression of Arbitrary Triangular Meshes',
        'Number of Authors': 3,
        'Author Position': 2,
        'Author Name': 'David Levin',
        'Author ID': np.NaN,
        'Author Affiliation': 'Tel Aviv University',
        'One Affiliation': True,
    },
    {
        'Year': 1999,
        'DOI': '10.1109/VIS.1999.10000',
        'Title': 'Progressive Compression of Arbitrary Triangular Meshes',
        'Number of Authors': 3,
        'Author Position': 3,
        'Author Name': 'Offir Remez',
        'Author ID': np.NaN,
        'Author Affiliation': 'Tel Aviv University',
        'One Affiliation': True,
    }
]

# %%
fill_data_df = pd.DataFrame(fill_data)

# %%
fill_data_df
# Out:
#    Year                     DOI  \
# 0  1999  10.1109/VIS.1999.10000
# 1  1999  10.1109/VIS.1999.10000
# 2  1999  10.1109/VIS.1999.10000
#
#                                                Title  Number of Authors  \
# 0  Progressive Compression of Arbitrary Triangula...                  3
# 1  Progressive Compression of Arbitrary Triangula...                  3
# 2  Progressive Compression of Arbitrary Triangula...                  3
#
#    Author Position      Author Name  Author ID   Author Affiliation  \
# 0                1  Daniel Cohen-Or        NaN  Tel Aviv University
# 1                2      David Levin        NaN  Tel Aviv University
# 2                3      Offir Remez        NaN  Tel Aviv University
#
#    One Affiliation
# 0             True
# 1             True
# 2             True

# %%
df_ieee = df_ieee[:-1].append(fill_data_df, ignore_index = True)
df_ieee
# Out:
#        Year                         DOI  \
# 0      2011       10.1109/TVCG.2011.185
# 1      2011       10.1109/TVCG.2011.185
# 2      2011       10.1109/TVCG.2011.185
# 3      1991  10.1109/VISUAL.1991.175815
# 4      1991  10.1109/VISUAL.1991.175815
# ...     ...                         ...
# 12407  2009       10.1109/TVCG.2009.199
# 12408  2009       10.1109/TVCG.2009.199
# 12409  1999      10.1109/VIS.1999.10000
# 12410  1999      10.1109/VIS.1999.10000
# 12411  1999      10.1109/VIS.1999.10000
#
#                                                    Title  Number of Authors  \
# 0                               D³ Data-Driven Documents                3.0
# 1                               D³ Data-Driven Documents                3.0
# 2                               D³ Data-Driven Documents                3.0
# 3      Tree-maps: a space-filling approach to the vis...                2.0
# 4      Tree-maps: a space-filling approach to the vis...                2.0
# ...                                                  ...                ...
# 12407                      Visual Human+Machine Learning                3.0
# 12408                      Visual Human+Machine Learning                3.0
# 12409  Progressive Compression of Arbitrary Triangula...                3.0
# 12410  Progressive Compression of Arbitrary Triangula...                3.0
# 12411  Progressive Compression of Arbitrary Triangula...                3.0
#
#        Author Position             Author Name  \
# 0                  1.0         Michael Bostock
# 1                  2.0        Vadim Ogievetsky
# 2                  3.0            Jeffrey Heer
# 3                  1.0              B. Johnson
# 4                  2.0          B. Shneiderman
# ...                ...                     ...
# 12407              2.0            Jürgen Waser
# 12408              3.0  Meister Eduard Groller
# 12409              1.0         Daniel Cohen-Or
# 12410              2.0             David Levin
# 12411              3.0             Offir Remez
#
#                                             Author ID  \
# 0      https://ieeexplore.ieee.org/author/37591067400
# 1      https://ieeexplore.ieee.org/author/38016292400
# 2      https://ieeexplore.ieee.org/author/37550791300
# 3      https://ieeexplore.ieee.org/author/37381975300
# 4      https://ieeexplore.ieee.org/author/37283016400
# ...                                               ...
# 12407  https://ieeexplore.ieee.org/author/38111592300
# 12408  https://ieeexplore.ieee.org/author/37282552200
# 12409                                             NaN
# 12410                                             NaN
# 12411                                             NaN
#
#                                       Author Affiliation One Affiliation
# 0      Computer Science Department, Stanford Universi...            True
# 1      Computer Science Department, Stanford Universi...            True
# 2      Computer Science Department, Stanford Universi...            True
# 3      Department of Computer Science & Human-Compute...            True
# 4      Department of Computer Science & Human-Compute...            True
# ...                                                  ...             ...
# 12407                              VRVis Vienna, Austria            True
# 12408         Technical University of of Vienna, Austria            True
# 12409                                Tel Aviv University            True
# 12410                                Tel Aviv University            True
# 12411                                Tel Aviv University            True
#
# [12412 rows x 9 columns]

# %% [markdown]
# # Write the update to function

# %%
def update_df_ieee(df, fill_data): # df here is df_ieee
    row_to_drop = df.index[df.DOI == '10.1109/TVCG.2008.157'].tolist()[0]
    df_dropped = df.drop([row_to_drop])
    df_dropped.loc[df_dropped.DOI == '10.1109/TVCG.2008.157', 'Number of Authors'] -= 1
    df_dropped.loc[df_dropped.DOI == '10.1109/TVCG.2008.157', 'Author Position'] -= 1.0
    df = df_dropped
    fill_data_df = pd.DataFrame(fill_data)
    df = df.append(fill_data_df, ignore_index = True)
    return df

# %%
df_ieee = pd.read_csv('../../data/interim/ieee_author_df.csv')

# %%
df_ieee_updated = update_df_ieee(df_ieee, fill_data)

# %%
# write to file
df_ieee_updated.to_csv("../../data/interim/ieee_author_df_concated_corrected.csv", index=False)

# %% [markdown]
# ## In IEEE, how many authors have more than one affiliation?

# %%
df_ieee = pd.read_csv('../../data/interim/ieee_author_df_concated.csv')

# %%
df_ieee.shape
# Out:
# (12575, 9)

# %%
df_ieee[df_ieee['One Affiliation'] != True]
# 333 authors (without dedups) contain more than one affiliation.
# Out:
#        Year                         DOI  \
# 5      1990  10.1109/VISUAL.1990.146402
# 8      1997  10.1109/VISUAL.1997.663860
# 42     2007     10.1109/TVCG.2007.70515
# 55     2007     10.1109/TVCG.2007.70582
# 93     1999  10.1109/VISUAL.1999.809883
# ...     ...                         ...
# 12275  2021   10.1109/tvcg.2021.3114786
# 12361  2021   10.1109/TVCG.2021.3114774
# 12532  2007     10.1109/TVCG.2007.70534
# 12534  2007     10.1109/TVCG.2007.70534
# 12574  1999      10.1109/VIS.1999.10000
#
#                                                    Title  Number of Authors  \
# 5      Parallel coordinates: a tool for visualizing m...                2.0
# 8      ROAMing terrain: Real-time Optimally Adapting ...                6.0
# 42     Toward a Deeper Understanding of the Role of I...                4.0
# 55     NodeTrix: a Hybrid Visualization of Social Net...                3.0
# 93     Multi-projector displays using camera-based re...                8.0
# ...                                                  ...                ...
# 12275  Scope2Screen: Focus+Context Techniques for Pat...               13.0
# 12361  A Design Space for Applying the Freytag’s Pyra...                8.0
# 12532  A Flexible Multi-Volume Shader Framework for A...                3.0
# 12534  A Flexible Multi-Volume Shader Framework for A...                3.0
# 12574  Progressive Compression of Arbitrary Triangula...                NaN
#
#        Author Position       Author Name  \
# 5                  1.0      A. Inselberg
# 8                  1.0     M. Duchaineau
# 42                 4.0        J.A. Jacko
# 55                 1.0    Nathalie Henry
# 93                 6.0         H. Towles
# ...                ...               ...
# 12275             11.0  Sandro Santagata
# 12361              1.0         Leni Yang
# 12532              1.0        John Plate
# 12534              3.0   Bernd Froehlich
# 12574              NaN               NaN
#
#                                             Author ID  \
# 5      https://ieeexplore.ieee.org/author/37294162600
# 8      https://ieeexplore.ieee.org/author/37267813100
# 42     https://ieeexplore.ieee.org/author/37428064500
# 55     https://ieeexplore.ieee.org/author/37839948300
# 93     https://ieeexplore.ieee.org/author/37298881100
# ...                                               ...
# 12275  https://ieeexplore.ieee.org/author/37089207124
# 12361  https://ieeexplore.ieee.org/author/37087102860
# 12532  https://ieeexplore.ieee.org/author/37087771711
# 12534  https://ieeexplore.ieee.org/author/37282977500
# 12574                                             NaN
#
#                                       Author Affiliation One Affiliation
# 5            IBM Scientific Center, Los Angeles, CA, USA           False
# 8                    Los Alamos National Laboratory, USA           False
# 42     School of Interactive Computing & GVU Center, ...           False
# 55                       University of Sydney, Australia           False
# 93     Department of Computer Science, North Carolina...           False
# ...                                                  ...             ...
# 12275  Brigham and Women's Hospital, Harvard Medical ...           False
# 12361  Intelligent Big Data Visualization Lab at Tong...           False
# 12532  Fraunhofer IAIS and Bauhaus, Universität Weima...           False
# 12534                        Universität Weimar, Germany           False
# 12574                                                NaN             NaN
#
# [334 rows x 9 columns]
