# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8,6)
from scipy.stats import ttest_ind
pd.set_option('display.max_columns', None)
import numpy as np
from collections import Counter
font = {'family' : 'Arial',
        'weight' : 'normal',
        'size'   : 16}
matplotlib.rc('font', **font)
import string
from scipy.stats import mannwhitneyu

# %%
df = pd.read_csv('../../data/processed/cleaned_paper_df.csv')
# Replace True/False to Yes/No
# Snippet: https://stackoverflow.com/a/45196807
bool_cols = df.columns[df.dtypes == 'bool']
df[bool_cols] = df[bool_cols].replace({True: 'Yes', False: 'No'})
df['PaperType'] = df['PaperType'].replace({'J': 'Jor.', 'C': 'Con.'})

# cutoff
cutoff_year = 2020
df = df[df['Year'] <= cutoff_year]

# %%
df
# Out:
#      Conference  Year                                              Title  \
# 0       InfoVis  2011                           D³ Data-Driven Documents
# 1           Vis  1991  Tree-maps: a space-filling approach to the vis...
# 2           Vis  1990  Parallel coordinates: a tool for visualizing m...
# 3       InfoVis  2006  Hierarchical Edge Bundles: Visualization of Ad...
# 4           Vis  1997  ROAMing terrain: Real-time Optimally Adapting ...
# ...         ...   ...                                                ...
# 3059       VAST  2020  Visual Analytics of Multivariate Event Sequenc...
# 3060       VAST  2020   Visual Causality Analysis of Event Sequence Data
# 3061       VAST  2020  Visual cohort comparison for spatial single-ce...
# 3062       VAST  2020  Visual Neural Decomposition to Explain Multiva...
# 3063       VAST  2020  VizCommender: Computing Text-Based Similarity ...
#
#                                DOI  FirstPage LastPage PaperType  \
# 0            10.1109/TVCG.2011.185     2301.0     2309      Jor.
# 1       10.1109/VISUAL.1991.175815      284.0      291      Con.
# 2       10.1109/VISUAL.1990.146402      361.0      378      Con.
# 3            10.1109/TVCG.2006.147      741.0      748      Jor.
# 4       10.1109/VISUAL.1997.663860       81.0       88      Con.
# ...                            ...        ...      ...       ...
# 3059  10.1109/VAST50239.2020.00009       36.0       47      Con.
# 3060     10.1109/TVCG.2020.3030465     1343.0     1352      Jor.
# 3061     10.1109/TVCG.2020.3030336      733.0      743      Jor.
# 3062     10.1109/TVCG.2020.3030420     1374.0     1384      Jor.
# 3063     10.1109/TVCG.2020.3030387      495.0      505      Jor.
#
#       OpenAlex Year OpenAlex Publication Date  OpenAlex ID  \
# 0              2011                2011-12-01  W2135415614
# 1              1991                1991-10-22  W2146872957
# 2              1990                1990-10-23  W2034694694
# 3              2006                2006-09-01  W2145640629
# 4              1997                1997-10-01  W2532506824
# ...             ...                       ...          ...
# 3059           2020                2020-10-01  W3118521601
# 3060           2021                2021-01-28  W3081850804
# 3061           2021                2021-01-28  W3034223044
# 3062           2021                2021-01-28  W3091769969
# 3063           2021                2021-05-20  W3092325673
#
#                                     OpenAlex Venue Name  OpenAlex First Page  \
# 0     IEEE Transactions on Visualization and Compute...               2301.0
# 1                                    ieee visualization                284.0
# 2                                    ieee visualization                361.0
# 3     IEEE Transactions on Visualization and Compute...                741.0
# 4                                    ieee visualization                 81.0
# ...                                                 ...                  ...
# 3059            visual analytics science and technology                 36.0
# 3060  IEEE Transactions on Visualization and Compute...               1343.0
# 3061  IEEE Transactions on Visualization and Compute...                733.0
# 3062  IEEE Transactions on Visualization and Compute...               1374.0
# 3063  IEEE Transactions on Visualization and Compute...                495.0
#
#       OpenAlex Last Page  Number of Pages  Number of References  \
# 0                 2309.0              9.0                    27
# 1                  291.0              8.0                    21
# 2                  378.0             18.0                    20
# 3                  748.0              8.0                    32
# 4                   88.0              8.0                    20
# ...                  ...              ...                   ...
# 3059                47.0             12.0                    49
# 3060              1352.0             10.0                    46
# 3061               743.0             11.0                    54
# 3062              1384.0             11.0                    59
# 3063               505.0             11.0                    38
#
#       Number of Concepts  Number of Citations  Number of Authors  \
# 0                      9                 2185                  3
# 1                     17                 1118                  2
# 2                     10                  993                  2
# 3                     13                  795                  1
# 4                     10                  586                  6
# ...                  ...                  ...                ...
# 3059                   8                    7                  5
# 3060                  10                    4                  6
# 3061                   9                    3                  7
# 3062                   7                    2                  4
# 3063                  11                   13                  3
#
#      Cross-type Collaboration Cross-country Collaboration With US Authors  \
# 0                          No                          No             Yes
# 1                          No                          No             Yes
# 2                          No                          No             Yes
# 3                          No                          No              No
# 4                          No                          No             Yes
# ...                       ...                         ...             ...
# 3059                       No                          No              No
# 3060                       No                         Yes             Yes
# 3061                       No                          No              No
# 3062                       No                          No              No
# 3063                      Yes                         Yes             Yes
#
#      Both Cross-type and Cross-country Collaboration  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
# ...                                              ...
# 3059                                              No
# 3060                                              No
# 3061                                              No
# 3062                                              No
# 3063                                             Yes
#
#                                              IEEE Title  \
# 0                              D³ Data-Driven Documents
# 1     Tree-maps: a space-filling approach to the vis...
# 2     Parallel coordinates: a tool for visualizing m...
# 3     Hierarchical Edge Bundles: Visualization of Ad...
# 4     ROAMing terrain: Real-time Optimally Adapting ...
# ...                                                 ...
# 3059  Visual Analytics of Multivariate Event Sequenc...
# 3060   Visual Causality Analysis of Event Sequence Data
# 3061  Visual cohort comparison for spatial single-ce...
# 3062  Visual Neural Decomposition to Explain Multiva...
# 3063  VizCommender: Computing Text-Based Similarity ...
#
#       Citation Counts on Google Scholar Award Award Name Award Track
# 0                                3647.0    No        NaN         NaN
# 1                                2191.0    No        NaN         NaN
# 2                                1688.0    No        NaN         NaN
# 3                                1349.0   Yes         BP     InfoVis
# 4                                1398.0    No        NaN         NaN
# ...                                 ...   ...        ...         ...
# 3059                                9.0    No        NaN         NaN
# 3060                               10.0    No        NaN         NaN
# 3061                                5.0    No        NaN         NaN
# 3062                                3.0    No        NaN         NaN
# 3063                               17.0    No        NaN         NaN
#
# [3064 rows x 27 columns]

# %%
citenum = 'Number of Citations'
gcitenum = 'Citation Counts on Google Scholar'

# %%
df[df['Award'].isin(['No', 'Con.'])]
# Out:
#      Conference  Year                                              Title  \
# 0       InfoVis  2011                           D³ Data-Driven Documents
# 1           Vis  1991  Tree-maps: a space-filling approach to the vis...
# 2           Vis  1990  Parallel coordinates: a tool for visualizing m...
# 4           Vis  1997  ROAMing terrain: Real-time Optimally Adapting ...
# 5           Vis  2003  Acceleration techniques for GPU-based volume r...
# ...         ...   ...                                                ...
# 3059       VAST  2020  Visual Analytics of Multivariate Event Sequenc...
# 3060       VAST  2020   Visual Causality Analysis of Event Sequence Data
# 3061       VAST  2020  Visual cohort comparison for spatial single-ce...
# 3062       VAST  2020  Visual Neural Decomposition to Explain Multiva...
# 3063       VAST  2020  VizCommender: Computing Text-Based Similarity ...
#
#                                DOI  FirstPage LastPage PaperType  \
# 0            10.1109/TVCG.2011.185     2301.0     2309      Jor.
# 1       10.1109/VISUAL.1991.175815      284.0      291      Con.
# 2       10.1109/VISUAL.1990.146402      361.0      378      Con.
# 4       10.1109/VISUAL.1997.663860       81.0       88      Con.
# 5      10.1109/VISUAL.2003.1250384      287.0      292      Con.
# ...                            ...        ...      ...       ...
# 3059  10.1109/VAST50239.2020.00009       36.0       47      Con.
# 3060     10.1109/TVCG.2020.3030465     1343.0     1352      Jor.
# 3061     10.1109/TVCG.2020.3030336      733.0      743      Jor.
# 3062     10.1109/TVCG.2020.3030420     1374.0     1384      Jor.
# 3063     10.1109/TVCG.2020.3030387      495.0      505      Jor.
#
#       OpenAlex Year OpenAlex Publication Date  OpenAlex ID  \
# 0              2011                2011-12-01  W2135415614
# 1              1991                1991-10-22  W2146872957
# 2              1990                1990-10-23  W2034694694
# 4              1997                1997-10-01  W2532506824
# 5              2003                2003-10-22  W2113001609
# ...             ...                       ...          ...
# 3059           2020                2020-10-01  W3118521601
# 3060           2021                2021-01-28  W3081850804
# 3061           2021                2021-01-28  W3034223044
# 3062           2021                2021-01-28  W3091769969
# 3063           2021                2021-05-20  W3092325673
#
#                                     OpenAlex Venue Name  OpenAlex First Page  \
# 0     IEEE Transactions on Visualization and Compute...               2301.0
# 1                                    ieee visualization                284.0
# 2                                    ieee visualization                361.0
# 4                                    ieee visualization                 81.0
# 5                                    ieee visualization                 38.0
# ...                                                 ...                  ...
# 3059            visual analytics science and technology                 36.0
# 3060  IEEE Transactions on Visualization and Compute...               1343.0
# 3061  IEEE Transactions on Visualization and Compute...                733.0
# 3062  IEEE Transactions on Visualization and Compute...               1374.0
# 3063  IEEE Transactions on Visualization and Compute...                495.0
#
#       OpenAlex Last Page  Number of Pages  Number of References  \
# 0                 2309.0              9.0                    27
# 1                  291.0              8.0                    21
# 2                  378.0             18.0                    20
# 4                   88.0              8.0                    20
# 5                   38.0              1.0                    17
# ...                  ...              ...                   ...
# 3059                47.0             12.0                    49
# 3060              1352.0             10.0                    46
# 3061               743.0             11.0                    54
# 3062              1384.0             11.0                    59
# 3063               505.0             11.0                    38
#
#       Number of Concepts  Number of Citations  Number of Authors  \
# 0                      9                 2185                  3
# 1                     17                 1118                  2
# 2                     10                  993                  2
# 4                     10                  586                  6
# 5                     20                  608                  2
# ...                  ...                  ...                ...
# 3059                   8                    7                  5
# 3060                  10                    4                  6
# 3061                   9                    3                  7
# 3062                   7                    2                  4
# 3063                  11                   13                  3
#
#      Cross-type Collaboration Cross-country Collaboration With US Authors  \
# 0                          No                          No             Yes
# 1                          No                          No             Yes
# 2                          No                          No             Yes
# 4                          No                          No             Yes
# 5                          No                          No              No
# ...                       ...                         ...             ...
# 3059                       No                          No              No
# 3060                       No                         Yes             Yes
# 3061                       No                          No              No
# 3062                       No                          No              No
# 3063                      Yes                         Yes             Yes
#
#      Both Cross-type and Cross-country Collaboration  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 4                                                 No
# 5                                                 No
# ...                                              ...
# 3059                                              No
# 3060                                              No
# 3061                                              No
# 3062                                              No
# 3063                                             Yes
#
#                                              IEEE Title  \
# 0                              D³ Data-Driven Documents
# 1     Tree-maps: a space-filling approach to the vis...
# 2     Parallel coordinates: a tool for visualizing m...
# 4     ROAMing terrain: Real-time Optimally Adapting ...
# 5     Acceleration techniques for GPU-based volume r...
# ...                                                 ...
# 3059  Visual Analytics of Multivariate Event Sequenc...
# 3060   Visual Causality Analysis of Event Sequence Data
# 3061  Visual cohort comparison for spatial single-ce...
# 3062  Visual Neural Decomposition to Explain Multiva...
# 3063  VizCommender: Computing Text-Based Similarity ...
#
#       Citation Counts on Google Scholar Award Award Name Award Track
# 0                                3647.0    No        NaN         NaN
# 1                                2191.0    No        NaN         NaN
# 2                                1688.0    No        NaN         NaN
# 4                                1398.0    No        NaN         NaN
# 5                                1279.0    No        NaN         NaN
# ...                                 ...   ...        ...         ...
# 3059                                9.0    No        NaN         NaN
# 3060                               10.0    No        NaN         NaN
# 3061                                5.0    No        NaN         NaN
# 3062                                3.0    No        NaN         NaN
# 3063                               17.0    No        NaN         NaN
#
# [2910 rows x 27 columns]

# %% [markdown]
# ## Plot boxplots with stripplots

# %%
vars = ['Cross-type Collaboration', 'Cross-country Collaboration',
       'With US Authors', 'Award', 'PaperType']
short_varname_dic = {
    'Cross-type Collaboration':'Cross-type',
    'Cross-country Collaboration':'Cross-country',
    'With US Authors':'W/ US Authors'
}

# %%
'Cross-type Collaboration' in short_varname_dic.keys()
# Out:
# True

# %%
f, axs = plt.subplots(5,1,
                      figsize=(9,10),
                      sharex=True,
                      sharey=False,
                      gridspec_kw=dict(height_ratios=[1,1,1,1,1]))
for var in vars:
    index = vars.index(var)
    g = sns.boxplot(x=df[citenum], y=df[var].astype(str), palette="Set2", ax=axs[index])
    g = sns.stripplot(x=df[citenum], y=df[var].astype(str), 
              size=2, color="orange", linewidth=0, ax=axs[index], alpha=0.2)
    if index != -1:
        g.set_xlabel("")
        g.set_xscale("log")
    else:
        g.set_xscale("log")
    if var in short_varname_dic.keys():
        g.set_ylabel(short_varname_dic[var])
    else:
        g.set_ylabel("Cross-Type")

# %%
f, axs = plt.subplots(5,1,
                      figsize=(9,8),
                      sharex=True,
                      sharey=False,
                      gridspec_kw=dict(height_ratios=[1,1,1,1,1]))
g0 = sns.boxplot(x=df[citenum], y=df['Award'].astype(str), palette="Set2", ax=axs[0])
g0 = sns.stripplot(x=df[citenum], y=df['Award'].astype(str), 
              size=2, color="orange", linewidth=0, ax=axs[0], alpha=0.2)
g0.set_xlabel("")
###########
g1 = sns.boxplot(x=df[citenum], 
                 y=df['Cross-type Collaboration'].astype(str), palette="Paired", ax=axs[1])
g1 = sns.stripplot(x=df[citenum], y=df['Cross-type Collaboration'].astype(str), 
              size=2, color="orange", linewidth=0, ax=axs[1], alpha=0.2)
g1.set_xlabel("")
g1.set_ylabel("Cross-Type")
#############
g2 = sns.boxplot(x=df[citenum], 
                 y=df['Cross-country Collaboration'].astype(str), palette="vlag", ax=axs[2])
g2 = sns.stripplot(x=df[citenum], y=df['Cross-country Collaboration'].astype(str), 
              size=2, color="orange", linewidth=0, ax=axs[2], alpha=.2)
g2.set_xlabel("")
g2.set_ylabel("Cross-Country")
################
g3 = sns.boxplot(x=df[citenum], 
                 y=df['With US Authors'].astype(str), palette="Paired", ax=axs[3])
g3 = sns.stripplot(x=df[citenum], y=df['With US Authors'].astype(str), 
              size=2, color="orange", linewidth=0, ax=axs[3], alpha=0.2)
g3.set_xlabel("")
g3.set_ylabel("US Authors")
##################
g4 = sns.boxplot(x=citenum, y='PaperType', data=df, palette="Set2", ax=axs[4])
g4 = sns.stripplot(x=citenum, y='PaperType', data=df,
              size=2, color="orange", linewidth=0, ax=axs[4], alpha=0.2)
g4.set_xscale("log")
g4.set_ylabel("Paper Type")
f.tight_layout()
f.savefig('../../results/figures/boxplots', dpi=100)

# %% [markdown]
# ## Citation distributions

# %%
ax = sns.kdeplot(df[citenum], label='OpenAlex')
g = sns.kdeplot(df[gcitenum], ax=ax, label='Google Scholar')

# %%
cits = df[citenum].sort_values(ascending=False).tolist()
dff = pd.DataFrame(cits, columns = ['citations'])
dff['pdf'] = dff['citations'] / sum(dff['citations'])
dff['cdf'] = dff['pdf'].cumsum()
dff['ccdf'] = 1 - dff['cdf']
dff = dff.reset_index()
dff['rank'] = (dff['index'] + 1)/dff.shape[0]
ax = dff.plot(x = 'rank', y = 'cdf', grid=True, label='OpenAlex')
ax.set_xlabel('Author percentile by citations in descending order')
ax.set_ylabel('CDF of citations')
#####
cits = df[gcitenum].dropna().sort_values(ascending=False).tolist()
dff = pd.DataFrame(cits, columns = ['citations'])
dff['pdf'] = dff['citations'] / sum(dff['citations'])
dff['cdf'] = dff['pdf'].cumsum()
dff['ccdf'] = 1 - dff['cdf']
dff = dff.reset_index()
dff['rank'] = (dff['index'] + 1)/dff.shape[0]
g = dff.plot(x = 'rank', y = 'cdf', grid=True, ax = ax, label='Google Scholar')
g.set_xlabel('Author percentile by citations in descending order')
# Out:
# Text(0.5, 0, 'Author percentile by citations in descending order')

# %%
f, axs = plt.subplots(2,2,
                      figsize=(14,10),
                      sharex=False,
                      sharey=False,
                      gridspec_kw=dict(height_ratios=[1,1]))
##### Corr plot
g0 = sns.regplot(x=citenum, y=gcitenum, data = df,
            line_kws={"color":"orange","alpha":0.3,"lw":2},
            ax = axs[0,0])
g0.set_xlabel('OpenAlex citations')
g0.set_ylabel('Google Scholar citations')
g0.text(-0.1, 1.1, 'A', transform=g0.transAxes, 
            size=20, weight='bold')

##### Citation Distribution
g1 = sns.kdeplot(df[citenum], ax=axs[0,1])
g1_2 = sns.kdeplot(df[gcitenum], ax=g1)
g1_2.text(-0.1, 1.1, 'B', transform=g1_2.transAxes, 
            size=20, weight='bold')

##### Percentile
## OpenAlex
cits = df[citenum].sort_values(ascending=False).tolist()
dff = pd.DataFrame(cits, columns = ['citations'])
dff['pdf'] = dff['citations'] / sum(dff['citations'])
dff['cdf'] = dff['pdf'].cumsum()
dff['ccdf'] = 1 - dff['cdf']
dff = dff.reset_index()
dff['rank'] = (dff['index'] + 1)/dff.shape[0]
g2 = dff.plot(x = 'rank', y = 'cdf', grid=True, label='OpenAlex', ax=axs[1,0])
g2.set_xlabel('Author percentile by citations in descending order')
g2.set_ylabel('CDF of citations')

### Google Scholar
cits = df[gcitenum].dropna().sort_values(ascending=False).tolist()
dff = pd.DataFrame(cits, columns = ['citations'])
dff['pdf'] = dff['citations'] / sum(dff['citations'])
dff['cdf'] = dff['pdf'].cumsum()
dff['ccdf'] = 1 - dff['cdf']
dff = dff.reset_index()
dff['rank'] = (dff['index'] + 1)/dff.shape[0]
g2_2 = dff.plot(x = 'rank', y = 'cdf', grid=True, ax = g2, label='Google Scholar')
g2_2.set_xlabel('Paper rank by citations (decsending) / total num. of papers')
g2_2.text(-0.1, 1.1, 'C', transform=g2_2.transAxes, 
            size=20, weight='bold')

###### Conference tracks
g3 = sns.violinplot(x='Conference', y=citenum, data = df, ax=axs[1,1])
g3.set_yscale("log")
g3.text(-0.1, 1.1, 'D', transform=g3.transAxes, 
            size=20, weight='bold')

##### Save fig
f.savefig('../../results/figures/citation_distributions', dpi=100)

# %%
# fig, axs = plt.subplots(2,2,figsize=(8,8))
# axs = axs.flat
# for n, ax in enumerate(axs):

# %% [markdown]
# ## Statistical analysis

# %%
df.corr().at[citenum, gcitenum]
# Out:
# 0.9790515027062813

# %%
for var in vars:
    cat1 = df[df[var].isin(['Yes', 'Jor.'])]
    cat2 = df[df[var].isin(['No', 'Con.'])]
    U, p = mannwhitneyu(cat1[citenum].tolist(), cat2[citenum].tolist())
    print(f'{var}')
    print(f'U: {U}')
    print(format(p, 'f'))
    print('─' * 30)
# Out:
# Cross-type Collaboration
# U: 869368.0
# 0.637056
# ──────────────────────────────
# Cross-country Collaboration
# U: 821711.5
# 0.080595
# ──────────────────────────────
# With US Authors
# U: 1100740.5
# 0.371816
# ──────────────────────────────
# Award
# U: 292878.0
# 0.000000
# ──────────────────────────────
# PaperType
# U: 1149716.5
# 0.334718
# ──────────────────────────────

# %%
print('Google Scholar')
for var in vars:
    cat1 = df[df[var].isin(['Yes', 'Jor.'])]
    cat2 = df[df[var].isin(['No', 'Con.'])]
    U, p = mannwhitneyu(cat1[gcitenum].dropna().tolist(), cat2[gcitenum].dropna().tolist())
    print(f'{var}')
    print(f'U: {U}')
    print(format(p, 'f'))
    print('─' * 30)
# Out:
# Google Scholar
# Cross-type Collaboration
# U: 847535.0
# 0.137685
# ──────────────────────────────
# Cross-country Collaboration
# U: 792587.5
# 0.001798
# ──────────────────────────────
# With US Authors
# U: 1103580.0
# 0.299381
# ──────────────────────────────
# Award
# U: 287031.0
# 0.000000
# ──────────────────────────────
# PaperType
# U: 1049321.0
# 0.000000
# ──────────────────────────────

# %%
print(df.groupby('PaperType')[gcitenum].mean())
# Out:
# PaperType
# Con.    96.390968
# Jor.    74.848645
# Name: Citation Counts on Google Scholar, dtype: float64
